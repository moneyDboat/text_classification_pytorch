# %%
from torchtext import data, datasets
from tqdm import tqdm
import pandas as pd
import torch

# %%
TEXT = data.Field(sequential=True, fix_length=500)
LABEL = data.Field(sequential=False, use_vocab=False)

# %%
class GrandDataset(data.Dataset):
    name = 'grand dataset'
    
    def __init__(self, path, text_field, label_field, test=False, **kwargs):
        fields = [('text', text_field), ('label', label_field)]
        examples = []
        csv_data = pd.read_csv(path)
        print('preparing examples...')
        for text, label in tqdm(zip(csv_data['word_seg'], csv_data['class'])):
            examples.append(data.Example.fromlist([text, label], fields))
        super(GrandDataset, self).__init__(examples, fields, **kwargs)

# %%
val_path = 'val_set.csv'
val = GrandDataset(val_path, text_field=TEXT, label_field=LABEL)
# Out:
# 590it [00:00, 5887.15it/s]
# preparing examples...
# 5700it [00:01, 5565.07it/s]

# %%
val.fields
# Out:
# {'label': <torchtext.data.field.Field at 0x7fb7db1b1710>,
#  'text': <torchtext.data.field.Field at 0x7fb7db1b16a0>}

# %%
print(val.examples[0].text)
# Out:
# ['816903', '669476', '487239', '520477', '631890', '457012', '50336', '847972', '268202', '54111', '161196', '512910', '995362', '684484', '1074421', '250930', '168220', '520477', '989957', '680465', '680091', '831037', '995362', '416932', '703615', '1019141', '913693', '1257332', '355504', '23698', '250930', '43194', '706185', '520477', '441513', '778803', '1014225', '538246', '54111', '1256802', '1033823', '915668', '1019141', '520477', '1091199', '305209', '1033823', '460600', '168220', '1121767', '874881', '1134165', '915668', '591069', '995362', '816903', '1208158', '1256802', '520477', '201133', '16882', '119390', '1269211', '685057', '520477', '625466', '441513', '939470', '956848', '73450', '1037123', '520477', '58833', '1025743', '1204907', '990423', '237289', '520477', '541144', '1257332', '490774', '456768', '133940', '816903', '426716', '920327', '1005034', '451388', '1033823', '354355', '995362', '563568', '63641', '54111', '1257332', '1033823', '560534', '1005034', '354355', '1000483', '77718', '984322', '520477', '752991', '400027', '1058680', '494878', '846717', '1033823', '354355', '876555', '846717', '803569', '920327', '846717', '10585', '920327', '349538', '600621', '846717', '811924', '920327', '846717', '506496', '775233', '814361', '49805', '1071452', '995362', '816903', '965936', '920327', '1142192', '182481', '1136696', '604915', '1040536', '995362', '1257332', '758716', '520477', '563568', '1057544', '192454', '1142192', '39765', '1033823', '611601', '785700', '348548', '886801', '520477', '967560', '584273', '250930', '783760', '554251', '554251', '769621', '954801', '854891', '919096', '956927', '520477', '204775', '739365', '878073', '663450', '727829', '520477', '568277', '788244', '162254', '460600', '373047', '1033823', '520477', '524739', '54111', '1257332', '41306', '325497', '563568', '396454', '250930', '327735', '177828', '520477', '1000496', '572675', '39765', '936162', '520477', '65859', '610577', '279781', '995362', '816903', '655002', '920327', '952474', '962042', '995362', '669476', '758716', '520477', '31046', '563568', '965957', '1033823', '366221', '902191', '520477', '944203', '902191', '520477', '400027', '952474', '967328', '520477', '1272886', '835740', '758716', '1163183', '766772', '192121', '454003', '520477', '918835', '962042', '460600', '389822', '192121', '1018377', '563568', '1279716', '520477', '1149037', '119099', '857269', '257985', '984322', '659080', '995362', '816903', '271975', '920327', '830856', '847972', '65726', '735799', '995362', '632142', '54111', '1239563', '520477', '4184', '325497', '1097161', '876802', '520477', '930754', '63641', '54111', '563568', '1033823', '1177290', '174851', '183909', '1204907', '1226448', '54111', '688901', '1049092', '935975', '678537', '811924', '876555', '192454', '460600', '849442', '1071452', '520477', '1090251', '184574', '287496', '863440', '54111', '457012', '279976', '967191', '366221', '914774', '995362', '240908', '293258', '460600', '1272886', '54111', '86697', '849442', '1154287', '846717', '520477', '766772', '869627', '984322', '177068', '520477', '833124', '1257332', '706185', '995362', '683284', '563568', '1257332', '758716', '1039033', '205323', '520477', '441513', '939470', '54111', '192242', '1033823', '846717', '430399', '607494', '1023730', '849442', '520477', '656938', '170639', '520477', '755950', '739365', '226582', '310106', '1033823', '1039033', '995362', '129533', '889228', '520477', '658131', '490774', '422098', '816903', '608182', '1226448']

# %%
import word2vec
# 构建Vocub
w2v_path = 'emb-100.bin'
w2v = word2vec.load(w2v_path)

# %%
w2v.vectors.shape
# Out:
# (683027, 100)
